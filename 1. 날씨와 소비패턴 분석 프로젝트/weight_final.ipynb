# %%
import pandas as pd
import numpy as np
dir = 'C:\\Users\\admin\\Documents\\카카오톡 받은 파일\\'
dir_1 = 'C:\\pythonworks\\miniminiproject\\data\\'

buy = pd.read_csv(dir +'buy2018_1.csv', encoding='euc-kr')
buy_1 = pd.read_csv(dir +'buy2018_2.csv', encoding='euc-kr')
buy.columns = [0,'date','sex','age','big_cat','sm_cat','qty']
buy_1.columns  = [0,'date','sex','age','big_cat','sm_cat','qty']

# %%
buy = buy.loc[buy['big_cat']=='식품']

# %%
buy_1 = buy_1.loc[buy_1['big_cat']=='식품']

# %%
buy.head()
# Out:
#    0      date sex  age big_cat sm_cat  qty
# 0  1  20180101   F   20      식품    가공란   37
# 1  2  20180101   F   30      식품    가공란   16
# 2  3  20180101   F   40      식품    가공란    9
# 3  4  20180101   F   50      식품    가공란    3
# 4  5  20180101   M   20      식품    가공란   13

# %%
weight.head(16)
# Out:
#     Unnamed: 0 행정구역별(읍면동)   연령별     총인구(명)  총인구_남자(명)  총인구_여자(명)  Unnamed: 6  \
# 0          0.0        강원도  20.0   190697.0   108768.0    81929.0   3744957.0
# 1          5.0        경기도  20.0  1788009.0   962827.0   825182.0   3744957.0
# 2         10.0       경상남도  20.0   388545.0   222717.0   165828.0   3744957.0
# 3         15.0       경상북도  20.0   316055.0   181779.0   134276.0   3744957.0
# 4         20.0      광주광역시  20.0   222294.0   116267.0   106027.0   3744957.0
# 5         25.0      대구광역시  20.0   329555.0   178071.0   151484.0   3744957.0
# 6         30.0      대전광역시  20.0   235527.0   125704.0   109823.0   3744957.0
# 7         35.0      부산광역시  20.0   451695.0   238101.0   213594.0   3744957.0
# 8         40.0      서울특별시  20.0  1502243.0   724643.0   777600.0   3744957.0
# 9         50.0      울산광역시  20.0   146688.0    84499.0    62189.0   3744957.0
# 10        55.0      인천광역시  20.0   404715.0   214038.0   190677.0   3744957.0
# ...

# %%
weight.head(16)
# Out:
#    행정구역별(읍면동)   age  man_weight  woman_weight
# 0         강원도  20.0    0.029044      0.024969
# 1         경기도  20.0    0.257100      0.251488
# 2        경상남도  20.0    0.059471      0.050539
# 3        경상북도  20.0    0.048540      0.040923
# 4       광주광역시  20.0    0.031046      0.032313
# 5       대구광역시  20.0    0.047550      0.046167
# 6       대전광역시  20.0    0.033566      0.033470
# 7       부산광역시  20.0    0.063579      0.065096
# 8       서울특별시  20.0    0.193498      0.236986
# 9       울산광역시  20.0    0.022563      0.018953
# 10      인천광역시  20.0    0.057154      0.058112
# 11       전라남도  20.0    0.029595      0.024864
# 12       전라북도  20.0    0.033630      0.031194
# 13    제주특별자치도  20.0    0.012040      0.011339
# 14       충청남도  20.0    0.047857      0.044279
# 15       충청북도  20.0    0.033766      0.029306

# %%
buy['age'] = buy['age'].astype('int64')
buy_1['age'] = buy_1['age'].astype('int64')
weight = pd.read_csv(dir_1 +'weight_2019 - 세종제외.csv')
weather = pd.read_csv(dir_1 +'weather_final.csv',  encoding='euc-kr')

# %%
weight = weight[['행정구역별(읍면동)', 'age', 'man_weight', 'woman_weight']]
weight = weight.sort_values(['age', '행정구역별(읍면동)'])

# %%
weight = weight.iloc[:-1,:]

# %%
weather_temp.iloc[:,:-1].head(16)
# Out:
#            지역명          일자  평균기온  최저기온  최고기온    강수계속시간      일강수량  최대풍속  평균풍속  \
# 0          강원도  2018-01-01  -4.5 -10.5   3.4  0.000001  0.000001   3.6   1.0
# 2190       경기도  2018-01-01  -1.7  -6.9   4.7  0.000001  0.000001   3.4   1.0
# 7300      경상남도  2018-01-01   1.8  -1.9   5.5  0.000001  0.000001   5.3   1.8
# 4380      경상북도  2018-01-01   2.0  -1.1   6.2  0.000001  0.000001   5.5   2.7
# 8030     광주광역시  2018-01-01   2.3  -1.0   7.1  0.000001  0.000001   3.7   1.6
# 5110     대구광역시  2018-01-01   1.3  -1.3   5.0  0.000001  0.000001   7.7   3.1
# 3650     대전광역시  2018-01-01  -0.7  -5.3   4.9  0.000001  0.000001   2.7   1.0
# 8760     부산광역시  2018-01-01   2.7  -1.1   7.4  0.000001  0.000001   7.6   2.7
# 730      서울특별시  2018-01-01  -1.3  -5.1   3.8  0.000001  0.000001   3.8   1.4
# 6570     울산광역시  2018-01-01   2.1  -0.4   6.2  0.000001  0.000001   7.1   3.3
# 1460     인천광역시  2018-01-01  -0.3  -2.7   2.7  0.000001  0.000001   2.9   1.6
# ...

# %%
weight.head(16)
# Out:
#    행정구역별(읍면동)   age  man_weight  woman_weight
# 0         강원도  20.0    0.029044      0.024969
# 1         경기도  20.0    0.257100      0.251488
# 2        경상남도  20.0    0.059471      0.050539
# 3        경상북도  20.0    0.048540      0.040923
# 4       광주광역시  20.0    0.031046      0.032313
# 5       대구광역시  20.0    0.047550      0.046167
# 6       대전광역시  20.0    0.033566      0.033470
# 7       부산광역시  20.0    0.063579      0.065096
# 8       서울특별시  20.0    0.193498      0.236986
# 9       울산광역시  20.0    0.022563      0.018953
# 10      인천광역시  20.0    0.057154      0.058112
# 11       전라남도  20.0    0.029595      0.024864
# 12       전라북도  20.0    0.033630      0.031194
# 13    제주특별자치도  20.0    0.012040      0.011339
# 14       충청남도  20.0    0.047857      0.044279
# 15       충청북도  20.0    0.033766      0.029306

# %%
df_1
# Out:
#            일자 성별  나이      평균기온      최저기온      최고기온        강수계속시간  \
# 0  2018-01-01  M  20 -0.235966 -4.336762  4.892267  1.000000e-06
# 1  2018-01-01  M  30 -0.298196 -4.425725  4.854722  1.000000e-06
# 2  2018-01-01  M  40 -0.230984 -4.351162  4.904043  1.000000e-06
# 3  2018-01-01  M  50 -0.161667 -4.248277  4.934429  1.000000e-06
# 4  2018-01-01  M  60 -0.092695 -4.151203  4.970371  1.000000e-06
# 5  2018-01-01  F  20 -0.310144 -4.399151  4.826528  1.000000e-06
# 6  2018-01-01  F  30 -0.311405 -4.428691  4.839655  1.000000e-06
# 7  2018-01-01  F  40 -0.233767 -4.341905  4.897093  1.000000e-06
# 8  2018-01-01  F  50 -0.161814 -4.234300  4.926291  1.000000e-06
# 9  2018-01-01  F  60 -0.087322 -4.134714  4.969423  1.000000e-06
#
#            일강수량      최대풍속      평균풍속  ...     평균상대습도     평균증기압      가조시간  \
# 0  1.000000e-06  4.447899  1.659248  ...  47.204877  2.710152  9.718557
# 1  1.000000e-06  4.400392  1.634611  ...  47.265918  2.699308  9.715814
# ...

# %%
weight
# Out:
#    행정구역별(읍면동)   age  man_weight  woman_weight
# 0         강원도  20.0    0.029044      0.024969
# 1         경기도  20.0    0.257100      0.251488
# 2        경상남도  20.0    0.059471      0.050539
# 3        경상북도  20.0    0.048540      0.040923
# 4       광주광역시  20.0    0.031046      0.032313
# 5       대구광역시  20.0    0.047550      0.046167
# 6       대전광역시  20.0    0.033566      0.033470
# 7       부산광역시  20.0    0.063579      0.065096
# 8       서울특별시  20.0    0.193498      0.236986
# 9       울산광역시  20.0    0.022563      0.018953
# 10      인천광역시  20.0    0.057154      0.058112
# 11       전라남도  20.0    0.029595      0.024864
# 12       전라북도  20.0    0.033630      0.031194
# 13    제주특별자치도  20.0    0.012040      0.011339
# 14       충청남도  20.0    0.047857      0.044279
# 15       충청북도  20.0    0.033766      0.029306

# %%
weight_temp = weight.iloc[:,2:]
weight_temp

weight_np = weight_temp.to_numpy()

weight_result = weight_np.T.reshape(2, 5, 16)

# %%
weather_temp = weather.loc[weather.일자 =='2018-01-01'].sort_values('지역명')
# Out:
#            지역명          일자  평균기온  최저기온  최고기온    강수계속시간      일강수량  최대풍속  평균풍속  \
# 0          강원도  2018-01-01  -4.5 -10.5   3.4  0.000001  0.000001   3.6   1.0
# 2190       경기도  2018-01-01  -1.7  -6.9   4.7  0.000001  0.000001   3.4   1.0
# 7300      경상남도  2018-01-01   1.8  -1.9   5.5  0.000001  0.000001   5.3   1.8
# 4380      경상북도  2018-01-01   2.0  -1.1   6.2  0.000001  0.000001   5.5   2.7
# 8030     광주광역시  2018-01-01   2.3  -1.0   7.1  0.000001  0.000001   3.7   1.6
# 5110     대구광역시  2018-01-01   1.3  -1.3   5.0  0.000001  0.000001   7.7   3.1
# 3650     대전광역시  2018-01-01  -0.7  -5.3   4.9  0.000001  0.000001   2.7   1.0
# 8760     부산광역시  2018-01-01   2.7  -1.1   7.4  0.000001  0.000001   7.6   2.7
# 730      서울특별시  2018-01-01  -1.3  -5.1   3.8  0.000001  0.000001   3.8   1.4
# 6570     울산광역시  2018-01-01   2.1  -0.4   6.2  0.000001  0.000001   7.1   3.3
# 1460     인천광역시  2018-01-01  -0.3  -2.7   2.7  0.000001  0.000001   2.9   1.6
# ...

# %%
df_1
# Out:
#            일자 성별  나이      평균기온      최저기온      최고기온        강수계속시간  \
# 0  2018-01-01  M  20 -0.235966 -4.336762  4.892267  1.000000e-06
# 1  2018-01-01  M  30 -0.298196 -4.425725  4.854722  1.000000e-06
# 2  2018-01-01  M  40 -0.230984 -4.351162  4.904043  1.000000e-06
# 3  2018-01-01  M  50 -0.161667 -4.248277  4.934429  1.000000e-06
# 4  2018-01-01  M  60 -0.092695 -4.151203  4.970371  1.000000e-06
# 5  2018-01-01  F  20 -0.310144 -4.399151  4.826528  1.000000e-06
# 6  2018-01-01  F  30 -0.311405 -4.428691  4.839655  1.000000e-06
# 7  2018-01-01  F  40 -0.233767 -4.341905  4.897093  1.000000e-06
# 8  2018-01-01  F  50 -0.161814 -4.234300  4.926291  1.000000e-06
# 9  2018-01-01  F  60 -0.087322 -4.134714  4.969423  1.000000e-06
#
#            일강수량      최대풍속      평균풍속  ...     평균상대습도     평균증기압      가조시간  \
# 0  1.000000e-06  4.447899  1.659248  ...  47.204877  2.710152  9.718557
# 1  1.000000e-06  4.400392  1.634611  ...  47.265918  2.699308  9.715814
# ...

# %%
weather_np= weather_temp.iloc[:, 2:].values
weather_result = weather_np.reshape(1, 16, 19)

mat_result = np.matmul(weight_result, weather_result)

mat_result.reshape(10,19)
# Out:
# array([[-2.35966100e-01, -4.33676154e+00,  4.89226667e+00,
#          1.00000000e-06,  1.00000000e-06,  4.44789860e+00,
#          1.65924821e+00,  2.30389847e+01,  4.72048765e+01,
#          2.71015240e+00,  9.71855728e+00,  8.42439772e+00,
#          7.61839162e+00,  5.84291382e-01, -2.83744139e-01,
#          1.29276208e+00,  1.86082211e+00,  4.11039125e+01,
#          2.18665173e+01],
#        [-2.98196150e-01, -4.42572491e+00,  4.85472242e+00,
#          1.00000000e-06,  1.00000000e-06,  4.40039222e+00,
#          1.63461114e+00,  2.29658497e+01,  4.72659183e+01,
#          2.69930767e+00,  9.71581355e+00,  8.41536220e+00,
#          7.49848771e+00,  6.04815754e-01, -3.32141801e-01,
#          1.27630252e+00,  1.83774181e+00,  4.09058761e+01,
#          2.19025980e+01],
#        [-2.30984354e-01, -4.35116210e+00,  4.90404297e+00,
#          1.00000000e-06,  1.00000000e-06,  4.45281552e+00,
#          1.65964974e+00,  2.31240548e+01,  4.74081488e+01,
# ...

# %%
weather.columns[2:-1]
# Out:
# Index(['평균기온', '최저기온', '최고기온', '강수계속시간', '일강수량', '최대풍속', '평균풍속', '최소상대습도',
#        '평균상대습도', '평균증기압', '가조시간', '합계일조시간', '합계일사량', '평균중하층운량', '평균지면온도',
#        '합계대형증발량', '합계소형증발량', 'PM10'],
#       dtype='object')

# %%
df_1 = pd.DataFrame(mat_result.reshape(10, 19))#남20-60, 여20-60
df_1.columns = weather.columns[2:]
df_1['일자'] = ['2018-01-01']*10
df_1['성별'] =['M']*5 +['F']*5
df_1['나이'] = list(np.arange(2, 7)*10)*2
df_1 = df_1[['일자','성별','나이','평균기온', '최저기온', '최고기온', '강수계속시간', '일강수량', '최대풍속', '평균풍속', '최소상대습도',
       '평균상대습도', '평균증기압', '가조시간', '합계일조시간', '합계일사량', '평균중하층운량', '평균지면온도',
       '합계대형증발량', '합계소형증발량', 'PM10']]

# %%
df_1
# Out:
#            일자 성별  나이      평균기온      최저기온      최고기온        강수계속시간  \
# 0  2018-01-01  M  20 -0.235966 -4.336762  4.892267  1.000000e-06
# 1  2018-01-01  M  30 -0.298196 -4.425725  4.854722  1.000000e-06
# 2  2018-01-01  M  40 -0.230984 -4.351162  4.904043  1.000000e-06
# 3  2018-01-01  M  50 -0.161667 -4.248277  4.934429  1.000000e-06
# 4  2018-01-01  M  60 -0.092695 -4.151203  4.970371  1.000000e-06
# 5  2018-01-01  F  20 -0.310144 -4.399151  4.826528  1.000000e-06
# 6  2018-01-01  F  30 -0.311405 -4.428691  4.839655  1.000000e-06
# 7  2018-01-01  F  40 -0.233767 -4.341905  4.897093  1.000000e-06
# 8  2018-01-01  F  50 -0.161814 -4.234300  4.926291  1.000000e-06
# 9  2018-01-01  F  60 -0.087322 -4.134714  4.969423  1.000000e-06
#
#            일강수량      최대풍속      평균풍속  ...     평균상대습도     평균증기압      가조시간  \
# 0  1.000000e-06  4.447899  1.659248  ...  47.204877  2.710152  9.718557
# 1  1.000000e-06  4.400392  1.634611  ...  47.265918  2.699308  9.715814
# ...

# %%
weather_2018 = weather['일자'].unique()[:365]

# %%
for i in weather_2018[1:]:
    weather_temp = weather.loc[weather.일자 ==i].sort_values('지역명')
    weather_np = weather_temp.iloc[:, 2:].values
    weather_result = weather_np.reshape(1, 16, 19)
    mat_result = np.matmul(weight_result, weather_result)
    df_2 = pd.DataFrame(mat_result.reshape(10, 19))#남20-60, 여20-60
    df_2.columns = weather.columns[2:]
    df_2['일자'] = [i]*10
    df_2['성별'] =['M']*5 +['F']*5
    df_2['나이'] = list(np.arange(2, 7)*10)*2
    df_1=pd.concat([df_1, df_2])

df_result = df_1[['일자','성별','나이','평균기온', '최저기온', '최고기온', '강수계속시간', '일강수량', '최대풍속', '평균풍속', '최소상대습도',
       '평균상대습도', '평균증기압', '가조시간', '합계일조시간', '합계일사량', '평균중하층운량', '평균지면온도',
       '합계대형증발량', '합계소형증발량', 'PM10']]

df_result
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# ...

# %%
df_result
# Out:
#             일자 성별  나이      평균기온      최저기온      최고기온        강수계속시간  \
# 0   2018-01-01  M  20 -0.230297 -4.326727  4.893892  1.000000e-06
# 1   2018-01-01  M  30 -0.282246 -4.399968  4.859433  1.000000e-06
# 2   2018-01-01  M  40 -0.224065 -4.337875  4.905134  1.000000e-06
# 3   2018-01-01  M  50 -0.150963 -4.229300  4.937268  1.000000e-06
# 4   2018-01-01  M  60 -0.078885 -4.129157  4.975556  1.000000e-06
# 5   2018-01-01  F  20 -0.297054 -4.382815  4.834099  1.000000e-06
# 6   2018-01-01  F  30 -0.294766 -4.404200  4.847087  1.000000e-06
# 7   2018-01-01  F  40 -0.226793 -4.328181  4.897524  1.000000e-06
# 8   2018-01-01  F  50 -0.148914 -4.212797  4.930596  1.000000e-06
# 9   2018-01-01  F  60 -0.074511 -4.114731  4.974418  1.000000e-06
# 0   2018-01-02  M  20 -0.062496 -4.131941  4.652757  1.954908e-02
# 1   2018-01-02  M  30 -0.123195 -4.165775  4.554431  1.636769e-02
# 2   2018-01-02  M  40 -0.043460 -4.134479  4.680193  1.915805e-02
# ...

# %%
df_result['sex'] = df_result['성별']
df_result['date'] = df_result['일자']
df_result['age'] = df_result['나이']

df_result.drop(['성별', '나이', '일자'], axis=1, inplace=True)

df_result = df_result[['date', 'sex', 'age','평균기온', '최저기온', '최고기온', '강수계속시간', '일강수량', '최대풍속', '평균풍속', '최소상대습도',
       '평균상대습도', '평균증기압', '가조시간', '합계일조시간', '합계일사량', '평균중하층운량', '평균지면온도',
       '합계대형증발량', '합계소형증발량', 'PM10']]

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3650 entries, 0 to 9
# Data columns (total 21 columns):
# date       3650 non-null object
# sex        3650 non-null object
# age        3650 non-null int64
# 평균기온       3650 non-null float64
# 최저기온       3650 non-null float64
# 최고기온       3650 non-null float64
# 강수계속시간     3650 non-null float64
# 일강수량       3650 non-null float64
# 최대풍속       3650 non-null float64
# 평균풍속       3650 non-null float64
# 최소상대습도     3650 non-null float64
# 평균상대습도     3650 non-null float64
# 평균증기압      3650 non-null float64
# 가조시간       3650 non-null float64
# 합계일조시간     3650 non-null float64
# 합계일사량      3650 non-null float64
# 평균중하층운량    3650 non-null float64
# 평균지면온도     3650 non-null float64
# 합계대형증발량    3650 non-null float64
# 합계소형증발량    3650 non-null float64
# PM10       3650 non-null float64
# dtypes: float64(18), int64(1), object(2)
# memory usage: 627.3+ KB

# %%
df_result['date']
# Out:
# 0    2018-01-01
# 1    2018-01-01
# 2    2018-01-01
# 3    2018-01-01
# 4    2018-01-01
# 5    2018-01-01
# 6    2018-01-01
# 7    2018-01-01
# 8    2018-01-01
# 9    2018-01-01
# 0    2018-01-02
# 1    2018-01-02
# 2    2018-01-02
# 3    2018-01-02
# 4    2018-01-02
# 5    2018-01-02
# 6    2018-01-02
# 7    2018-01-02
# 8    2018-01-02
# 9    2018-01-02
# 0    2018-01-03
# 1    2018-01-03
# 2    2018-01-03
# 3    2018-01-03
# 4    2018-01-03
# 5    2018-01-03
# 6    2018-01-03
# 7    2018-01-03
# 8    2018-01-03
# 9    2018-01-03
#         ...
# 0    2018-12-29
# 1    2018-12-29
# 2    2018-12-29
# 3    2018-12-29
# 4    2018-12-29
# 5    2018-12-29
# 6    2018-12-29
# 7    2018-12-29
# 8    2018-12-29
# 9    2018-12-29
# 0    2018-12-30
# 1    2018-12-30
# 2    2018-12-30
# 3    2018-12-30
# 4    2018-12-30
# 5    2018-12-30
# 6    2018-12-30
# 7    2018-12-30
# 8    2018-12-30
# 9    2018-12-30
# 0    2018-12-31
# 1    2018-12-31
# 2    2018-12-31
# 3    2018-12-31
# ...

# %%
df_result['date'] = df_result.date.str.replace('-','')

# %%
buy = buy.append(buy_1)

# %%
buy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600612 entries, 0 to 507466
# Data columns (total 7 columns):
# 0          600612 non-null int64
# date       600612 non-null int64
# sex        600612 non-null object
# age        600612 non-null int64
# big_cat    600612 non-null object
# sm_cat     600612 non-null object
# qty        600612 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 36.7+ MB

# %%
buy['date'] = buy.date.astype('str')

# %%
buy_2018_result = pd.merge(buy, df_result, how='inner', on=['date', 'sex', 'age'])

# %%
buy_2018_result
# Out:
#              0      date sex  age big_cat        sm_cat  qty      평균기온  \
# 0            1  20180101   F   20      식품           가공란   37 -0.297054
# 1           12  20180101   F   20      식품           가자미    3 -0.297054
# 2           20  20180101   F   20      식품  갈비/찜/바비큐용 돈육    7 -0.297054
# 3           26  20180101   F   20      식품        갈비용 우육    1 -0.297054
# 4           28  20180101   F   20      식품            갈치    2 -0.297054
# 5           37  20180101   F   20      식품          감/홍시    6 -0.297054
# 6           47  20180101   F   20      식품    감귤/한라봉/오렌지  105 -0.297054
# 7           57  20180101   F   20      식품    감마리놀렌산 영양제    3 -0.297054
# 8           65  20180101   F   20      식품          감말랭이    1 -0.297054
# 9           72  20180101   F   20      식품            감자   40 -0.297054
# 10          88  20180101   F   20      식품           건강즙    2 -0.297054
# 11          96  20180101   F   20      식품        건강즙/녹용    6 -0.297054
# ...

# %%
buy_2018_result.to_csv(dir_1+'buy_2018_base_.csv',encoding='euc-kr')

# %%
df= buy_2018_result

# %%
df
# Out:
#             date sex  age         sm_pr  quant      평균기온      최저기온      최고기온  \
# 0       20190101   F   20           가공란     33 -2.964733 -6.449131  1.314196
# 1       20190101   F   20  갈비/찜/바비큐용 돈육      3 -2.964733 -6.449131  1.314196
# 2       20190101   F   20        갈비용 우육      6 -2.964733 -6.449131  1.314196
# 3       20190101   F   20            갈치      4 -2.964733 -6.449131  1.314196
# 4       20190101   F   20          감/홍시      1 -2.964733 -6.449131  1.314196
# 5       20190101   F   20    감귤/한라봉/오렌지     91 -2.964733 -6.449131  1.314196
# 6       20190101   F   20    감마리놀렌산 영양제      2 -2.964733 -6.449131  1.314196
# 7       20190101   F   20            감자     24 -2.964733 -6.449131  1.314196
# 8       20190101   F   20           갓김치      1 -2.964733 -6.449131  1.314196
# 9       20190101   F   20           건강즙      8 -2.964733 -6.449131  1.314196
# 10      20190101   F   20        건강즙/녹용      8 -2.964733 -6.449131  1.314196
# ...

# %%
ee = df.groupby('sm_pr').mean()[['quant']].sort_values('quant')

inde = list(ee.loc[ee.quant<=20.0].index)

len(inde)
# Out:
# 161
