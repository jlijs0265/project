# %%
import numpy as np
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_bootstrap_components as dbc
import plotly.express as px
import dash_table
import datetime

# %%
buy_2018 = pd.read_csv('C://pythonworks/miniminiproject/data/buy_2018.csv',  encoding='euc-kr')
buy_2018 = buy_2018.iloc[:,1:]
buy_2018['date'] = pd.to_datetime(buy_2018['date'])
buy_2018['age'] = buy_2018['age'].astype('str')

# %%
weight = pd.read_csv('C://pythonworks/miniminiproject/data/pop_2018.csv',  encoding='euc-kr')

# %%
pop_sum_2018 = weight['총인구_여자(명)'].sum()

# %%
pop_sum_2018
# Out:
# 18214337

# %%
weight['총인구_남자(명)']/pop_sum_2018
# Out:
# 0     0.005796
# 1     0.004819
# 2     0.006176
# 3     0.007002
# 4     0.005196
# 5     0.049918
# 6     0.055872
# 7     0.061559
# 8     0.057193
# 9     0.033337
# 10    0.011808
# 11    0.013210
# 12    0.014971
# 13    0.015143
# 14    0.010245
# 15    0.009640
# 16    0.009446
# 17    0.010826
# 18    0.012163
# 19    0.009196
# 20    0.006029
# 21    0.005549
# 22    0.006614
# 23    0.006191
# 24    0.003708
# 25    0.009483
# 26    0.008693
# 27    0.010392
# 28    0.010975
# 29    0.007273
#         ...
# 55    0.011171
# 56    0.012215
# 57    0.013175
# 58    0.013382
# 59    0.008103
# 60    0.005675
# 61    0.005681
# 62    0.007261
# 63    0.008257
# 64    0.006085
# 65    0.006622
# 66    0.005753
# 67    0.007442
# 68    0.007881
# 69    0.005817
# 70    0.002333
# 71    0.002499
# 72    0.003058
# 73    0.002827
# 74    0.001748
# 75    0.008290
# 76    0.008966
# 77    0.009484
# 78    0.009187
# 79    0.006351
# 80    0.006548
# 81    0.006080
# 82    0.006785
# ...

# %%
weight.loc[weight['행정구역별(읍면동)']=='서울특별시']
# Out:
#     Unnamed: 0 행정구역별(읍면동)  연령별   총인구(명)  총인구_남자(명)  총인구_여자(명)     가중치_남  \
# 40          40      서울특별시   20  1490977     725833     765144  0.019496
# 41          41      서울특별시   30  1542820     776948     765872  0.020868
# 42          42      서울특별시   40  1556709     775842     780867  0.020839
# 43          43      서울특별시   50  1543618     748398     795220  0.020102
# 44          44      서울특별시   60  1137430     538323     599107  0.014459
#
#        가중치_여
# 40  0.020551
# 41  0.020571
# 42  0.020974
# 43  0.021359
# 44  0.016092

# %%
weight.loc[weight.연령별==20,:]
# Out:
#     Unnamed: 0 행정구역별(읍면동)  연령별   총인구(명)  총인구_남자(명)  총인구_여자(명)     가중치_남  \
# 0            0        강원도   20   192236     110222      82014  0.002961
# 5            5        경기도   20  1767281     949263     818018  0.025497
# 10          10       경상남도   20   393322     224549     168773  0.006031
# 15          15       경상북도   20   319936     183327     136609  0.004924
# 20          20      광주광역시   20   218905     114641     104264  0.003079
# 25          25      대구광역시   20   331747     180334     151413  0.004844
# 30          30      대전광역시   20   236256     126722     109534  0.003404
# 35          35      부산광역시   20   458036     241822     216214  0.006495
# 40          40      서울특별시   20  1490977     725833     765144  0.019496
# 45          45    세종특별자치시   20    38475      20433      18042  0.000549
# 50          50      울산광역시   20   150027      86189      63838  0.002315
# 55          55      인천광역시   20   402803     212428     190375  0.005706
# ...

# %%
weight
# Out:
#     Unnamed: 0 행정구역별(읍면동)  연령별   총인구(명)  총인구_남자(명)  총인구_여자(명)     가중치_남
# 0            0        강원도   20   192236     110222      82014  0.002961
# 1            1        강원도   30   175037      91649      83388  0.002462
# 2            2        강원도   40   227360     117451     109909  0.003155
# 3            3        강원도   50   262361     133155     129206  0.003576
# 4            4        강원도   60   199417      98808     100609  0.002654
# 5            5        경기도   20  1767281     949263     818018  0.025497
# 6            6        경기도   30  2030946    1062478     968468  0.028538
# 7            7        경기도   40  2293704    1170632    1123072  0.031443
# 8            8        경기도   50  2147857    1087599    1060258  0.029212
# 9            9        경기도   60  1283106     633954     649152  0.017028
# 10          10       경상남도   20   393322     224549     168773  0.006031
# 11          11       경상남도   30   466831     251214     215617  0.006747
# ...

# %%
weight['가중치_남'] = weight['총인구_남자(명)']/pop_sum_2018

# %%
weight['가중치_여'] = weight['총인구_여자(명)']/pop_sum_2018

# %%
weight[['가중치_남','가중치_여']].sum()
# Out:
# 가중치_남    1.0
# 가중치_여    1.0
# dtype: float64

# %%
weight = pd.read_csv()
# Out:
#     Unnamed: 0 행정구역별(읍면동)  연령별   총인구(명)  총인구_남자(명)  총인구_여자(명)     가중치_남  \
# 0            0        강원도   20   192236     110222      82014  0.005796
# 1            1        강원도   30   175037      91649      83388  0.004819
# 2            2        강원도   40   227360     117451     109909  0.006176
# 3            3        강원도   50   262361     133155     129206  0.007002
# 4            4        강원도   60   199417      98808     100609  0.005196
# 5            5        경기도   20  1767281     949263     818018  0.049918
# 6            6        경기도   30  2030946    1062478     968468  0.055872
# 7            7        경기도   40  2293704    1170632    1123072  0.061559
# 8            8        경기도   50  2147857    1087599    1060258  0.057193
# 9            9        경기도   60  1283106     633954     649152  0.033337
# 10          10       경상남도   20   393322     224549     168773  0.011808
# 11          11       경상남도   30   466831     251214     215617  0.013210
# ...

# %%
weight_2018 = pd.read_csv('C://pythonworks/miniminiproject/data/pop_2019.csv',  encoding='u')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-144-92020d6b9081> in <module>
# ----> 1 weight_2018 = pd.read_csv('C://pythonworks/miniminiproject/data/pop_2019.csv',  encoding='euc-kr')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
wheather
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37c86dede5a4> in <module>
# ----> 1 wheather
#
# NameError: name 'wheather' is not defined

# %%
weight.loc[weight.연령별==20]['가중치_남'].shape
# Out:
# (17,)

# %%
weight['행정구역별(읍면동)'].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도'], dtype=object)

# %%
wheather.loc[wheather.일시 =='2018-01-01']['평균기온'].shape
# Out:
# (16,)

# %%
wheather.head()
# Out:
#    지점명          일시  평균기온  최저기온  최고기온  강수계속시간  일강수량  최대풍속  평균풍속  최소상대습도  ...  \
# 0  강원도  2018-01-01  -4.5 -10.5   3.4     NaN   NaN   3.6   1.0    20.0  ...
# 1  강원도  2018-01-02  -3.5  -9.4   3.5     NaN   NaN   4.2   1.2    23.0  ...
# 2  강원도  2018-01-03  -5.6 -10.6   0.9     NaN   NaN   2.6   0.9    30.0  ...
# 3  강원도  2018-01-04  -6.1 -11.7  -0.8     NaN   NaN   1.6   0.6    41.0  ...
# 4  강원도  2018-01-05  -4.2  -8.4   1.9     NaN   NaN   3.3   1.2    37.0  ...
#
#    가조시간  합계일조시간  합계일사량  일최심신적설  일최심적설  평균중하층운량  평균지면온도  합계대형증발량  합계소형증발량  \
# 0   9.6     8.0  10.90     NaN    NaN      NaN    -2.8      1.2      1.7
# 1   9.6     7.8   9.22     NaN    NaN      NaN    -3.5      1.2      1.8
# 2   9.6     8.0   9.75     NaN    NaN      NaN    -4.3      0.9      1.3
# 3   9.6     7.1   8.76     NaN    NaN      NaN    -4.5      0.7      0.9
# 4   9.7     6.9   8.43     NaN    NaN      NaN    -3.7      0.9      1.3
#
#    안개계속시간
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...

# %%
np.where((buy_2018.sex=='M')&(buy_2018.age==20), weight.loc[weight.연령별==20][weight.'가중치_남'],0) * np.where((buy_2018.date=='2018-01-01')&(wheather.일시 =='2018-01-01'),wheather.loc[wheather.일시 =='2018-01-01']['평균기온'],0)

# %%
wheather[['지점명','일시','평균기온']].지점명.unique()
# Out:
# array(['강원도', '서울특별시', '인천광역시', '경기도', '충청북도', '대전광역시', '경상북도', '대구광역시',
#        '전라북도', '울산광역시', '경상남도', '광주광역시', '부산광역시', '전라남도', '제주특별자치도',
#        '충청남도', '세종특별자치시'], dtype=object)

# %%
if (weight['행정구역별(읍면동)'] == wheather.지점명) & (buy_2018_1.sex == 'M') :
    a = weight.가중치_남 * wheater.평균기온
    print(wheather.지점명,buy_2018_1.sex,a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-757adf7bd0b1> in <module>
# ----> 1 if (weight['행정구역별(읍면동)'] == wheather.지점명) & (buy_2018_1.sex == 'M') :
#       2     a = weight.가중치_남 * wheater.평균기온
#       3     print(wheather.지점명,buy_2018_1.sex,a)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1674
#    1675         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1676             raise ValueError("Can only compare identically-labeled "
#    1677                              "Series objects")
#    1678
#
# ValueError: Can only compare identically-labeled Series objects

# %%
buy_2018_1
# Out:
#             date sex  age         sm_pr  quant  year month day
# 0       20180101   F   20           가공란     37  2018    01  01
# 1       20180101   F   30           가공란     16  2018    01  01
# 2       20180101   F   40           가공란      9  2018    01  01
# 3       20180101   F   50           가공란      3  2018    01  01
# 4       20180101   M   20           가공란     13  2018    01  01
# 5       20180101   M   30           가공란      6  2018    01  01
# 6       20180101   M   40           가공란      6  2018    01  01
# 7       20180101   F   20           가자미      3  2018    01  01
# 8       20180101   F   30           가자미      5  2018    01  01
# 9       20180101   F   40           가자미      4  2018    01  01
# 10      20180101   F   50           가자미      2  2018    01  01
# 11      20180101   M   30           가자미      2  2018    01  01
# 12      20180101   M   40           가자미      1  2018    01  01
# 13      20180101   M   50           가자미      3  2018    01  01
# ...

# %%
wheather = wheather.fillna(0)
wheather.iloc[625:628,:] = (21.2+17.9)/2
wheather.iloc[625:628,:]
# Out:
#        지점명     일시   평균기온   최저기온   최고기온  강수계속시간   일강수량   최대풍속   평균풍속  최소상대습도  \
# 625  19.55  19.55  19.55  19.55  19.55   19.55  19.55  19.55  19.55   19.55
# 626  19.55  19.55  19.55  19.55  19.55   19.55  19.55  19.55  19.55   19.55
# 627  19.55  19.55  19.55  19.55  19.55   19.55  19.55  19.55  19.55   19.55
#
#      ...   가조시간  합계일조시간  합계일사량  일최심신적설  일최심적설  평균중하층운량  평균지면온도  합계대형증발량  \
# 625  ...  19.55   19.55  19.55   19.55  19.55    19.55   19.55    19.55
# 626  ...  19.55   19.55  19.55   19.55  19.55    19.55   19.55    19.55
# 627  ...  19.55   19.55  19.55   19.55  19.55    19.55   19.55    19.55
#
#      합계소형증발량  안개계속시간
# 625    19.55   19.55
# 626    19.55   19.55
# 627    19.55   19.55
#
# [3 rows x 22 columns]

# %%
sm = buy_2018_1.sm_pr.unique()

sm_cat_pie = dcc.Graph(
    id = 'sm_cat_pie',
    figure = px.pie(pivit_df,values = 'quant',names = 'pie_name')

)

month_pie = dcc.Graph(
    id = 'month_pie',
    figure = px.pie(buy_2018_1,values = 'quant',names = 'month')

)
sm_cat_bar = dcc.Graph(
    id = 'sm_cat_bar',
    figure = px.bar(pivit_df,x ='quant',y = 'pie_name')
)

# %%
app = dash.Dash(external_stylesheets=[dbc.themes.GRID])
app.layout = html.Div(
    [
    html.H1(),
    sm_cat_pie,
    sm_cat_bar,
    month_pie
    
    ]
)
app.run_server(host = '192.168.0.65',port = '80')
# Out:
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
# Dash is running on http://192.168.0.65:80/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.0.65:80/ (Press CTRL+C to quit)
# 192.168.0.65 - - [26/May/2021 12:05:00] "GET / HTTP/1.1" 200 -
# 192.168.0.65 - - [26/May/2021 12:05:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.0.65 - - [26/May/2021 12:05:00] "GET /_favicon.ico?v=1.20.0 HTTP/1.1" 200 -
# ...
