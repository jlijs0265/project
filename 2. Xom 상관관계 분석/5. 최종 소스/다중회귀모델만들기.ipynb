# %%
import pandas as pd

# %%
Day = pd.read_csv('day_input.csv')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size= 0.1, random_state=10)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
print(mean_squared_error(reg.predict(X_test),y_test))
print(r2_score(reg.predict(X_test),y_test))
# Out:
# 0.04211704944060235
# -4.841057690838395

# %%
X = Day.iloc[:,:-1]
Y = Day.iloc[:,-1:]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size= 0.3, random_state=10)
reg = linear_model.LinearRegression()
# Out:
# 0.022675904837529636
# -0.21086792524422115

# %%
reg.fit(X_train, y_train)
reg.coef_
print(mean_squared_error(reg.predict(X_test),y_test))
print(r2_score(reg.predict(X_test),y_test))

# %%
answer = pd.DataFrame(reg.predict(X_test))

# %%
answer['y_test'] = y_test.reset_index().Y

# %%
y_test.reset_index().Y
# Out:
# 0      0.428767
# 1      0.908405
# 2      0.242013
# 3      0.661868
# 4      0.932949
#          ...
# 856    0.751817
# 857    0.798026
# 858    0.773207
# 859    0.793912
# 860    0.416015
# Name: Y, Length: 861, dtype: float64

# %%
answer
# Out:
#             0    y_test
# 0    0.679811  0.428767
# 1    0.827714  0.908405
# 2    0.416145  0.242013
# 3    0.779075  0.661868
# 4    0.814650  0.932949
# ..        ...       ...
# 856  0.587591  0.751817
# 857  0.753885  0.798026
# 858  0.554390  0.773207
# 859  0.532436  0.793912
# 860  0.685808  0.416015
#
# [861 rows x 2 columns]

# %%
answer = answer.rename(columns={0:'predict'})

# %%
answer.plot.scatter(x = 'predict', y = 'y_test')
# Out:
# <AxesSubplot:xlabel='predict', ylabel='y_test'>
